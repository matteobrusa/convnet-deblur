# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage import io, color
from scipy.signal import convolve2d as conv2
from skimage import color, data, restoration
from pprint import pprint

def showpics(pics, cols=2):
    plt.gray()
    plt.rcParams["figure.figsize"] = 16, 16
    n= len(pics)

    rows= int((n+1)/cols)

    r= 1
    c= 1
    i= 1
    
    for pic in pics:
        if (c>cols):
            c= 0
            r+= 1
        
        plt.subplot(rows, cols, i)
        plt.imshow(pic)
        plt.title(i)
        
        i+= 1
        c+= 1
        plt.axis('off')
            
    plt.gray()
    plt.subplots_adjust(wspace=0.01, hspace=0.1, top=1, bottom=0, left=0, right=1)
    plt.show()    
    
    return

# %%
import numpy as np
from skimage import io
import scipy.signal
from PIL import Image

swirls_count= 256
photos_count= 100

swirls= np.load("swirls4x32.npy")

for n in range(100):
    
    image_name= str(100+n)+'.jpg'
    img= io.imread("images/src/" + image_name)
    swirl= swirls[n]
    blurred =scipy.signal.convolve2d(img, swirl, 'same') ## change to mirror or full

    img_path= "images/blurred/" + str(n) +"_" + image_name
    Image.fromarray((blurred*255).astype("uint8"), mode="L").save(img_path)
    
    print("saved " + img_path)
      
    if (n<10):
        showpics([img, swirl, blurred],3)
# Out:
# saved images/blurred/0_100.jpg
# saved images/blurred/1_101.jpg
# saved images/blurred/2_102.jpg
# saved images/blurred/3_103.jpg
# saved images/blurred/4_104.jpg
# saved images/blurred/5_105.jpg
# saved images/blurred/6_106.jpg
# saved images/blurred/7_107.jpg
# saved images/blurred/8_108.jpg
# saved images/blurred/9_109.jpg
# saved images/blurred/10_110.jpg
# saved images/blurred/11_111.jpg
# saved images/blurred/12_112.jpg
# saved images/blurred/13_113.jpg
# saved images/blurred/14_114.jpg
# saved images/blurred/15_115.jpg
# saved images/blurred/16_116.jpg
# saved images/blurred/17_117.jpg
# saved images/blurred/18_118.jpg
# saved images/blurred/19_119.jpg
# saved images/blurred/20_120.jpg
# saved images/blurred/21_121.jpg
# saved images/blurred/22_122.jpg
# saved images/blurred/23_123.jpg
# saved images/blurred/24_124.jpg
# saved images/blurred/25_125.jpg
# saved images/blurred/26_126.jpg
# saved images/blurred/27_127.jpg
# saved images/blurred/28_128.jpg
# ...
